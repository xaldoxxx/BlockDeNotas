# %% [markdown]
# <a href="https://colab.research.google.com/github/xaldoxxx/BlockDeNotas/blob/main/cv2practica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# jugando con cv2

# %% [markdown]
# probando los metodos de conversion de colores

# %%
import cv2
from google.colab.patches import *

# %%
image = cv2.imread('/content/image.jpg', cv2.IMREAD_UNCHANGED)

# %%
image_grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
image_bgr2hls = cv2.cvtColor(image, cv2.COLOR_BGR2HLS)

# %%
image_BGR2HSV_FULL = cv2.cvtColor(image, cv2.COLOR_BGR2HSV_FULL)

# %%
image_BGR2LAB = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)

# %%
cv2_imshow(image_grayscale), cv2_imshow(image), cv2_imshow(image_bgr2hls), cv2_imshow(image_bgr2hls), cv2_imshow(image_BGR2HSV_FULL), cv2_imshow(image_BGR2LAB)
# Out:
# <PIL.Image.Image image mode=L size=615x370 at 0x7F327DCE6390>
# <PIL.Image.Image image mode=RGB size=615x370 at 0x7F327DD46090>
# <PIL.Image.Image image mode=RGB size=615x370 at 0x7F327DD465D0>
# <PIL.Image.Image image mode=RGB size=615x370 at 0x7F327DD465D0>
# <PIL.Image.Image image mode=RGB size=615x370 at 0x7F327DD465D0>
# <PIL.Image.Image image mode=RGB size=615x370 at 0x7F327DD46090>
# (None, None, None, None, None, None)

# %%
import numpy as np

# %%
canvas = np.zeros(image.shape, np.uint8)

# %%
canvas.fill(255)

# %%
mask = np.zeros(image.shape, np.uint8)

# %%
mask.fill(255)

# %%
new_background = np.zeros(image.shape, np.uint8)

# %%
new_background.fill(255)

# %%
thresh, image_edges = patches.cv2_threshold(image_gray, 100, 255, cv2.THRESH_BINARY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-7e27a86c04a6> in <module>()
# ----> 1 thresh, image_edges = patches.cv2_threshold(image_gray, 100, 255, cv2.THRESH_BINARY)
#
# NameError: name 'patches' is not defined

# %%
cv2_

# %%
contours_draw, hierachy = cv2.findContours(image_edges, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3a01c7fd2bb0> in <module>()
#       1
# ----> 2 contours_draw, hierachy = cv2.findContours(image_edges, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
#
# NameError: name 'image_edges' is not defined
